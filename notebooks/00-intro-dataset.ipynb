# %% [markdown]
# # 00 - Introduccion al dataset
#
# Seccion **3.1 Introduccion** del informe.

# %% [markdown]
# ## Consigna
#
# Describir el dataset: origen, que representa cada fila/columna, definir la variable objetivo y el tipo de problema (clasificacion o regresion).
#
# - Origen y fuente del dataset.
# - Descripcion de filas (unidad observacional) y columnas (features).
# - Variable objetivo (target).
# - Tipo de problema: clasificacion / regresion.

# %%
# TODO
